# %% [markdown]
# There are 4 datasets that we are considering. We wanted to merge the datasets into one dataset and then started with data cleaning and preprocessing.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('data/raw/imdb_movies.csv')
print(df1.head())
print(df1.info())
print(df1.describe())
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
# ...

# %%
df2 = pd.read_csv('data/raw/mbti.csv')
print(df2.head())
print(df2.info())
print(df2.describe())
# Out:
#           stat  mbti enneagram                     role  \
# 0  697 / 162    ESFP       7w6  Peter Quill "Star-Lord"
# 1  668 / 231    ESFP       8w7         Anakin Skywalker
# 2  589 / 243    ESFP       6w7              Ron Weasley
# 3  312 / 101    ESFP       7w8      Bellatrix Lestrange
# 4  302 / 105    ESFP       7w6                    Simba
#
#                           movie  \
# 0     Marvel Cinematic Universe
# 1                     Star Wars
# 2      Harry Potter (franchise)
# 3      Harry Potter (franchise)
# 4          The Lion King (1994)
#
#                                              img_url
# 0  https://www.personality-database.com/profile_i...
# 1  https://www.personality-database.com/profile_i...
# 2  https://www.personality-database.com/profile_i...
# 3  https://www.personality-database.com/profile_i...
# 4  https://www.personality-database.com/profile_i...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18741 entries, 0 to 18740
# ...

# %%
df3 = pd.read_csv('data/raw/imdb_db.csv')
print(df3.head())
print(df3.info())
print(df3.describe())
# Out:
#                            Movie Name  Movie Date Serie Name Serie Date  \
# 0                          Les évadés      1994.0        NaN        NaN
# 1  The Dark Knight: Le chevalier noir      2008.0        NaN        NaN
# 2                           Inception      2010.0        NaN        NaN
# 3                          Fight Club      1999.0        NaN        NaN
# 4                        Pulp Fiction      1994.0        NaN        NaN
#
#                           Movie Type  Number of Votes  Movie Revenue (M$)  \
# 0                          ['Drama']          2294987          28341469.0
# 1       ['Action', 'Crime', 'Drama']          2259829         534858444.0
# 2  ['Action', 'Adventure', 'Sci-Fi']          2021865         292576195.0
# 3                          ['Drama']          1819635          37030102.0
# 4                 ['Crime', 'Drama']          1792272         107928762.0
#
#    Score  Metascore  Time Duration (min)               Director  \
# ...

# %%
df4 = pd.read_csv('data/raw/imdb_database.csv')
print(df4.head())
print(df4.info())
print(df4.describe())
# Out:
#                            Movie Name Movie Date Serie Name Serie Date  \
# 0                          Les évadés     (1994)       None       None
# 1  The Dark Knight: Le chevalier noir     (2008)       None       None
# 2                           Inception     (2010)       None       None
# 3                          Fight Club     (1999)       None       None
# 4                        Pulp Fiction     (1994)       None       None
#
#                   Movie Type  Number of Votes Movie Revenue (M$)  Score  \
# 0                      Drama          2294987           28341469    9.3
# 1       Action, Crime, Drama          2259829          534858444    9.0
# 2  Action, Adventure, Sci-Fi          2021865          292576195    8.8
# 3                      Drama          1819635           37030102    8.8
# 4               Crime, Drama          1792272          107928762    8.9
#
#   Metascore Time Duration (min)               Director  \
# ...
